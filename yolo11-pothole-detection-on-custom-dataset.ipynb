# %% [markdown]
# <a href="https://www.kaggle.com/code/hosen42/yolo11n-pothole-detection-on-custom-dataset?scriptVersionId=219357186" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Data: https://universe.roboflow.com/smartathon/new-pothole-detection/dataset/2#

# %%
# !nvidia-smi

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📗 Step 01 # Install the Ultralytics Package</h1></center>

# %%
# !pip install ultralytics

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📗 Step 02 # Import All the Requried Libraries</h1></center>

# %%
import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO
from IPython.display import Image

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📗 Step # 03 Download Dataset from Roboflow</h1></center>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="2G1fzmGjBqDSvB6Ff01t")
project = rf.workspace("smartathon").project("new-pothole-detection")
version = project.version(2)
dataset = version.download("yolov11")

# %%
dataset.location

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📗 Step # 03 Download Dataset from Roboflow</h1></center>

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model="yolo11n.pt" epochs=200 imgsz=640

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📗 Step # 05 Examine Training Results</h1></center>

# %%
Image("/kaggle/working/runs/detect/train/confusion_matrix.png", width=800)

# %%
Image("/kaggle/working/runs/detect/train/confusion_matrix_normalized.png", width=800)

# %%
Image("/kaggle/working/runs/detect/train/labels.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/labels_correlogram.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/results.png", width=800)

# %%
Image("/kaggle/working/runs/detect/train/F1_curve.png", width=800)

# %%
Image("/kaggle/working/runs/detect/train/PR_curve.png", width=800)

# %%
Image("/kaggle/working/runs/detect/train/P_curve.png", width=800)

# %%
Image("/kaggle/working/runs/detect/train/R_curve.png", width=800)

# %%
Image("/kaggle/working/runs/detect/train/train_batch0.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/train_batch1.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/train_batch2.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/train_batch34290.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/val_batch0_labels.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/val_batch0_pred.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/val_batch0_labels.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/val_batch1_pred.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/val_batch2_labels.jpg", width=800)

# %%
Image("/kaggle/working/runs/detect/train/val_batch2_pred.jpg", width=800)

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📗 Step # 07  Validate Fine-Tuned Model</h1></center>

# %%
# !yolo task=detect mode=val model="/kaggle/working/runs/detect/train/weights/best.pt" data={dataset.location}/data.yaml

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📗 Step # 08 Inference with Custom Model on Images</h1></center>

# %%
# !yolo task=detect mode=predict model="/kaggle/working/runs/detect/train/weights/best.pt" conf=0.25 source={dataset.location}/test/images save=True

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/kaggle/working/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:4]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %%
# !pip install gdown

# %%
# !gdown "https://drive.google.com/uc?id=1Ic9O-cWLjfHsqnE1HEPfbNLg1TOKio0X"

# %%
# !yolo task=detect mode=predict model= "/kaggle/working/runs/detect/train/weights/best.pt" conf=0.25 source=pothole.jpg save=True

# %%
Image("/kaggle/working/runs/detect/predict2/pothole.jpg", width=800)

# %% [markdown]
# <center><h1 style='background-color:#99ccff;padding:10px;font-family:courier'>📗 Step # 08 Inference with Custom Model on Videos</h1></center>

# %%
# !gdown "https://drive.google.com/uc?id=1D47Vj-v_l6t8JsRsntugAuMX9txgly27"

# %%
# !yolo task=detect mode=predict model= "/kaggle/working/runs/detect/train/weights/best.pt" conf=0.25 source="pothole.mp4" save=True

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/kaggle/working/runs/detect/predict3/pothole.avi'

# Compressed video path
compressed_path = "/kaggle/working/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
